# %% [markdown]
# <a href="https://colab.research.google.com/github/Perla-arellano/Probabilidad-y-estad-stica-/blob/main/Unidad4/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PROBABILIDAD Y ESTADISTICA
# Distribucion normal
# ejercicio 1
#
# unidad 4

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Generar datos para la distribución normal
media = 70  #media
desv_std = 5  #desviacion estandar
num_datos = 500
# generamos los datos de manera aleatoria y Lon ponemos en una Lista (array)
datos = np. random.normal(media, desv_std, num_datos)
datos[0:50] # Mostrar los primeros 50
# Out:
# array([66.40806985, 74.17508881, 67.85352883, 74.01532187, 69.44347261,
#        74.45401386, 66.74776154, 68.41740119, 74.04937489, 67.57149305,
#        72.2896344 , 74.01202079, 69.40601654, 67.44024781, 69.21989059,
#        68.61138844, 69.66312523, 67.72408331, 69.71032924, 68.6149499 ,
#        72.1366593 , 73.13893217, 78.40938191, 65.61593591, 67.31987248,
#        68.83020443, 70.99698516, 68.75255257, 65.67069681, 67.34531538,
#        68.07752416, 65.32211964, 68.76483317, 72.90563089, 75.95036454,
#        74.81735462, 66.02755791, 70.53664724, 66.63654405, 78.38205992,
#        72.61887762, 60.14175701, 77.85613266, 65.91793339, 60.45324346,
#        73.54946275, 74.42206166, 75.66091633, 65.23321884, 70.90525361])

# %%
#crear un rango de valores para crear una densidad
x = np.linspace(media - 3 * desv_std, media + 3 * desv_std, num_datos)
# Calcular la PDF de la distribución normal
pdf = 1 / (desv_std * np.sqrt(2 * np.pi)) * np.exp(-(x - media)**2 / (2 * desv_std **2))

# %%
# Para no imprimir toda la Lista de valores (500), desplegamos los primeros 50
print("Imprimir los primeros 50 Valores de x", x[0:50], " , y los primeros 50 pdf", pdf[0:50])
# Out:
# Imprimir los primeros 50 Valores de x [55.         55.06012024 55.12024048 55.18036072 55.24048096 55.3006012
#  55.36072144 55.42084168 55.48096192 55.54108216 55.6012024  55.66132265
#  55.72144289 55.78156313 55.84168337 55.90180361 55.96192385 56.02204409
#  56.08216433 56.14228457 56.20240481 56.26252505 56.32264529 56.38276553
#  56.44288577 56.50300601 56.56312625 56.62324649 56.68336673 56.74348697
#  56.80360721 56.86372745 56.9238477  56.98396794 57.04408818 57.10420842
#  57.16432866 57.2244489  57.28456914 57.34468938 57.40480962 57.46492986
#  57.5250501  57.58517034 57.64529058 57.70541082 57.76553106 57.8256513
#  57.88577154 57.94589178]  , y los primeros 50 pdf [0.00088637 0.00091886 0.0009524  0.00098703 0.00102277 0.00105964
#  0.00109769 0.00113694 0.00117742 0.00121917 0.00126222 0.0013066
#  0.00135234 0.00139948 0.00144805 0.0014981  0.00154965 0.00160274
#  0.00165741 0.0017137  0.00177164 0.00183128 0.00189265 0.0019558
#  0.00202076 0.00208757 0.00215629 0.00222694 0.00229958 0.00237424
#  0.00245097 0.00252981 0.00261082 0.00269403 0.00277949 0.00286724
#  0.00295734 0.00304983 0.00314475 0.00324216 0.00334211 0.00344464
#  0.0035498  0.00365764 0.00376822 0.00388157 0.00399776 0.00411683
#  0.00423883 0.00436382]

# %%
# Graficar histograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, color='b')
plt.title('Distribución Normal ')
plt.xlabel('Peso en kg de los estudiantes')
plt. grid(True)
plt.show()

# %%
# Visualizar la PDF|
plt. figure(figsize=(6, 4))
plt.plot(x, pdf, label='Normal: (media: (); ds:())'.format(np.round(media, 2), np.round(desv_std, 2)))
plt.title('Función de Densidad de Probabilidad (PDF) - Distribución Normal')
plt.xlabel('Pesos en Kg. de los estudiantes')
plt.ylabel( 'Densidad de Probabilidad')
plt. legend()
plt. grid(True)
plt. show()

# %%
# Graficar histograma
plt. figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b')
plt. plot( x, pdf, 'k', linewidth=2, )
plt.title( 'Distribución Normal ')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()

# %% [markdown]
# EJERCICIO 2

# %%
plt.figure(figsize=(6, 4))

#Parametros de la distribucion normal
media= 70 #media
desv_std= 4 # Desviación estándar
total_estudiantes = 500
# VARIABLE para Cálculo de la probabilidad de que un estudiante que pese menos de 75 kg
peso_limite = 79
# Primero necesitamos calcular la probabilidad de que un estudiante pese menos
# de 75 kg utilizando la función de distribución acumulativa (CDF) de la distribución normal
prob_menos_75kg = norm.cdf(peso_limite, media, desv_std)
# Cálculo del número de estudiantes que pesan menos de 75 kg
estudiantes_menos_75kg = total_estudiantes * prob_menos_75kg
print("Probabilidad de que un estudiante pese menos de 75 kg:", prob_menos_75kg)
print("Número de estudiantes que pesan menos de 75 kg:", estudiantes_menos_75kg)
# Graficar la distribución normal
x = np. linspace(media - 4 * desv_std, media + 4 * desv_std, 1000)
y = norm.pdf(x, media, desv_std)
plt.plot(x, y, 'b', linewidth=2)
plt. fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt. title( 'Probabilidad de que un estudiante pese menos de 75 kg. \n $\mu=70$, $\sigma=45, X=500')
plt.xlabel( 'Peso (kg)')
plt.ylabel('Densidad de probabilidad')
plt. grid(True)
plt. show()
# Out:
# Probabilidad de que un estudiante pese menos de 75 kg: 0.9877755273449553
# Número de estudiantes que pesan menos de 75 kg: 493.88776367247766

# %%
# Calcular la función de densidad de probabilidad de la distribución normal
x = np. linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)
plt.plot(x, y,'b', linewidth=2)
plt.fill_between(x, y, where=(x >= peso_limite), color='skyblue', alpha=0.5)
plt. title('Probabilidad de que un estudiante pese mas de 79 Kg. \n $\mu=70$, $|sigma=4$, X=500')
plt.xlabel( 'Peso (kg)')
plt.ylabel('Densidad de probabilidad')
plt. grid (True)
plt.show()
