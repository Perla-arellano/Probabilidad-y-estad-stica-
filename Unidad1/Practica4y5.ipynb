# %% [markdown]
# <a href="https://colab.research.google.com/github/Perla-arellano/Probabilidad-y-estad-stica-/blob/main/Unidad1/Practica4y5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# unidad1.probabilidad y estadistica
#
# practica4
# #Tablas de frecuencias
#
# alumna:Arellano santillan Perla yesenia
#
# docente:Dr rodriguez rivas jose gabriel

# %%
import random
edades=[]
for i in range(100):
  numero_aleatorio = random.randint(18,70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [57, 57, 34, 29, 64, 54, 42, 53, 36, 22, 55, 30, 18, 27, 38, 51, 44, 61, 46, 54, 45, 41, 55, 50, 26, 62, 18, 56, 57, 55, 31, 37, 64, 37, 47, 62, 42, 21, 48, 26, 29, 35, 48, 52, 70, 55, 35, 23, 51, 38, 55, 18, 37, 55, 35, 55, 34, 62, 18, 59, 21, 43, 34, 68, 49, 65, 26, 24, 39, 57, 40, 63, 70, 26, 21, 24, 51, 23, 18, 57, 22, 48, 54, 68, 51, 46, 32, 24, 58, 64, 18, 31, 26, 56, 52, 28, 42, 57, 30, 21]

# %%
import pandas as pd

# %%
#crear un dataframe de pandas con los numeros aleatoriod
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    57
# 1    57
# 2    34
# 3    29
# 4    64

# %%
#calcular la tabla de distribucion de recuencias
tabla_frecuencias = df[ 'Edad']. value_counts() .reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')
# Imprimir la tabla de distribución de frecuencias print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
#     Edad  Frecuencia
# 2     18           6
# 4     21           4
# 22    22           2
# 16    23           2
# 6     24           3
# 3     26           5
# 34    27           1
# 44    28           1
# 15    29           2
# 24    30           2
# 20    31           2
# 32    32           1
# 10    34           3
# 7     35           3
# 38    36           1
# 9     37           3
# 19    38           2
# 27    39           1
# 30    40           1
# 40    41           1
# 14    42           3
# 26    43           1
# 43    44           1
# 41    45           1
# 23    46           2
# 36    47           1
# 8     48           3
# 29    49           1
# 39    50           1
# 5     51           4
# 18    52           2
# 37    53           1
# 12    54           3
# 0     55           7
# 21    56           2
# 1     57           6
# 33    58           1
# 35    59           1
# 42    61           1
# 11    62           3
# 31    63           1
# 13    64           3
# 28    65           1
# 25    68           2
# 17    70           2

# %%
tabla_frecuencias['Frec Relativa']= tabla_frecuencias['Frecuencia'] /100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 2     18           6           0.06
# 4     21           4           0.04
# 22    22           2           0.02
# 16    23           2           0.02
# 6     24           3           0.03
# 3     26           5           0.05
# 34    27           1           0.01
# 44    28           1           0.01
# 15    29           2           0.02
# 24    30           2           0.02
# 20    31           2           0.02
# 32    32           1           0.01
# 10    34           3           0.03
# 7     35           3           0.03
# 38    36           1           0.01
# 9     37           3           0.03
# 19    38           2           0.02
# 27    39           1           0.01
# 30    40           1           0.01
# 40    41           1           0.01
# 14    42           3           0.03
# 26    43           1           0.01
# 43    44           1           0.01
# 41    45           1           0.01
# 23    46           2           0.02
# 36    47           1           0.01
# 8     48           3           0.03
# 29    49           1           0.01
# 39    50           1           0.01
# 5     51           4           0.04
# 18    52           2           0.02
# 37    53           1           0.01
# 12    54           3           0.03
# 0     55           7           0.07
# 21    56           2           0.02
# 1     57           6           0.06
# 33    58           1           0.01
# 35    59           1           0.01
# 42    61           1           0.01
# 11    62           3           0.03
# 31    63           1           0.01
# 13    64           3           0.03
# 28    65           1           0.01
# 25    68           2           0.02
# 17    70           2           0.02

# %%
tabla_frecuencias['Frec Porcentual']= tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 2     18           6           0.06              6.0
# 4     21           4           0.04              4.0
# 22    22           2           0.02              2.0
# 16    23           2           0.02              2.0
# 6     24           3           0.03              3.0
# 3     26           5           0.05              5.0
# 34    27           1           0.01              1.0
# 44    28           1           0.01              1.0
# 15    29           2           0.02              2.0
# 24    30           2           0.02              2.0
# 20    31           2           0.02              2.0
# 32    32           1           0.01              1.0
# 10    34           3           0.03              3.0
# 7     35           3           0.03              3.0
# 38    36           1           0.01              1.0
# 9     37           3           0.03              3.0
# 19    38           2           0.02              2.0
# 27    39           1           0.01              1.0
# 30    40           1           0.01              1.0
# 40    41           1           0.01              1.0
# 14    42           3           0.03              3.0
# 26    43           1           0.01              1.0
# 43    44           1           0.01              1.0
# 41    45           1           0.01              1.0
# 23    46           2           0.02              2.0
# 36    47           1           0.01              1.0
# 8     48           3           0.03              3.0
# 29    49           1           0.01              1.0
# 39    50           1           0.01              1.0
# 5     51           4           0.04              4.0
# 18    52           2           0.02              2.0
# 37    53           1           0.01              1.0
# 12    54           3           0.03              3.0
# 0     55           7           0.07              7.0
# 21    56           2           0.02              2.0
# 1     57           6           0.06              6.0
# 33    58           1           0.01              1.0
# 35    59           1           0.01              1.0
# 42    61           1           0.01              1.0
# 11    62           3           0.03              3.0
# 31    63           1           0.01              1.0
# 13    64           3           0.03              3.0
# 28    65           1           0.01              1.0
# 25    68           2           0.02              2.0
# 17    70           2           0.02              2.0

# %%
tabla_frecuencias['Frec Acumulada']= tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 2     18           6           0.06              6.0               6
# 4     21           4           0.04              4.0              10
# 22    22           2           0.02              2.0              12
# 16    23           2           0.02              2.0              14
# 6     24           3           0.03              3.0              17
# 3     26           5           0.05              5.0              22
# 34    27           1           0.01              1.0              23
# 44    28           1           0.01              1.0              24
# 15    29           2           0.02              2.0              26
# 24    30           2           0.02              2.0              28
# 20    31           2           0.02              2.0              30
# 32    32           1           0.01              1.0              31
# 10    34           3           0.03              3.0              34
# 7     35           3           0.03              3.0              37
# 38    36           1           0.01              1.0              38
# 9     37           3           0.03              3.0              41
# 19    38           2           0.02              2.0              43
# 27    39           1           0.01              1.0              44
# 30    40           1           0.01              1.0              45
# 40    41           1           0.01              1.0              46
# 14    42           3           0.03              3.0              49
# 26    43           1           0.01              1.0              50
# 43    44           1           0.01              1.0              51
# 41    45           1           0.01              1.0              52
# 23    46           2           0.02              2.0              54
# 36    47           1           0.01              1.0              55
# 8     48           3           0.03              3.0              58
# 29    49           1           0.01              1.0              59
# 39    50           1           0.01              1.0              60
# 5     51           4           0.04              4.0              64
# 18    52           2           0.02              2.0              66
# 37    53           1           0.01              1.0              67
# 12    54           3           0.03              3.0              70
# 0     55           7           0.07              7.0              77
# 21    56           2           0.02              2.0              79
# 1     57           6           0.06              6.0              85
# 33    58           1           0.01              1.0              86
# 35    59           1           0.01              1.0              87
# 42    61           1           0.01              1.0              88
# 11    62           3           0.03              3.0              91
# 31    63           1           0.01              1.0              92
# 13    64           3           0.03              3.0              95
# 28    65           1           0.01              1.0              96
# 25    68           2           0.02              2.0              98
# 17    70           2           0.02              2.0             100

# %% [markdown]
# Regla de sturges
# 1. Es una regla que sirve para calcular el número de clases o intervalos idóneo en los que se debe
# dividir un conjunto de datos.
# 2. Establece que el número de clases es igual a uno más el logaritmo en base dos del número total de datos.
#
# c = 1 + log2 (N)
# donde N es el tamaño de la muestra.

# %%
import math

# %%
print(edades)
# Out:
# [57, 57, 34, 29, 64, 54, 42, 53, 36, 22, 55, 30, 18, 27, 38, 51, 44, 61, 46, 54, 45, 41, 55, 50, 26, 62, 18, 56, 57, 55, 31, 37, 64, 37, 47, 62, 42, 21, 48, 26, 29, 35, 48, 52, 70, 55, 35, 23, 51, 38, 55, 18, 37, 55, 35, 55, 34, 62, 18, 59, 21, 43, 34, 68, 49, 65, 26, 24, 39, 57, 40, 63, 70, 26, 21, 24, 51, 23, 18, 57, 22, 48, 54, 68, 51, 46, 32, 24, 58, 64, 18, 31, 26, 56, 52, 28, 42, 57, 30, 21]

# %%
df = pd. DataFrame ({'Edad': edades})
df
# Out:
#     Edad
# 0     57
# 1     57
# 2     34
# 3     29
# 4     64
# ..   ...
# 95    28
# 96    42
# 97    57
# 98    30
# 99    21
#
# [100 rows x 1 columns]

# %%
# Calcular el número de intervalos utilizando la regla de Sturges
n = len (edades)
K = int( 1 + math. log2(100))
print("Valor de n=",n, " \nNúmero de intervalos =", K)
# Out:
# Valor de n= 100
# Número de intervalos = 7

# %%
#crear la tabla de frecuencia
tabla_frecuencia = pd. cut( df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (47.714, 55.143]    22
# 1  (17.947, 25.429]    17
# 2  (25.429, 32.857]    14
# 3  (32.857, 40.286]    14
# 4  (55.143, 62.571]    14
# 5  (40.286, 47.714]    10
# 6    (62.571, 70.0]     9

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 1  (17.947, 25.429]    17
# 2  (25.429, 32.857]    14
# 3  (32.857, 40.286]    14
# 5  (40.286, 47.714]    10
# 0  (47.714, 55.143]    22
# 4  (55.143, 62.571]    14
# 6    (62.571, 70.0]     9

# %%
# Generar columnas siguientes
tabla_frecuencia[ 'Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia[ 'Frec Porc'] = tabla_frecuencia[ 'Frec'] / n * 100
tabla_frecuencia[ 'Frec Ac'] = tabla_frecuencia[ 'Frec'].cumsum()
tabla_frecuencia[ 'Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia[ 'Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum( )
# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 1  (17.947, 25.429]    17      0.17       17.0       17         0.17
# 2  (25.429, 32.857]    14      0.14       14.0       31         0.31
# 3  (32.857, 40.286]    14      0.14       14.0       45         0.45
# 5  (40.286, 47.714]    10      0.10       10.0       55         0.55
# 0  (47.714, 55.143]    22      0.22       22.0       77         0.77
# 4  (55.143, 62.571]    14      0.14       14.0       91         0.91
# 6    (62.571, 70.0]     9      0.09        9.0      100         1.00
#
#    Frec Porc Ac
# 1          17.0
# 2          31.0
# 3          45.0
# 5          55.0
# 0          77.0
# 4          91.0
# 6         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha =0.5)
plt.title("histograma de edades basado en la funcion de matploitlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'histograma de edades basado en la funcion de matploitlib con valores estandar')

# %%
# Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=K, alpha = 0.5)
plt. title('Histograma de edades basado en la regla de Sturges')
plt.xlabel( 'Edades')
plt.ylabel( 'Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ##unidad1.Probabilidad y estadistica##
# #practica5: Diagrama de cajas y bigotes#
#
# Alumna:Arellano Sabtillan Perla Yesenia

# %%
edades2 = []
# Hacemos un ciclo para generar 100
for i in range (100):
# generamos un numero aleatorio con la
# numero_aleatorio funcion randint y lo guardamos en la variable
  numero_aleatorio = random.randint( 20, 87 )
# Agregamos el numero aleatorio a la lista de valores
  edades2. append (numero_aleatorio)
print(edades2)
# Out:
# [25, 81, 65, 43, 31, 81, 58, 20, 71, 68, 34, 86, 46, 38, 24, 84, 57, 55, 30, 50, 38, 71, 76, 34, 77, 32, 49, 31, 61, 71, 24, 58, 28, 77, 36, 48, 65, 67, 29, 77, 81, 47, 66, 73, 41, 31, 45, 75, 86, 74, 70, 69, 67, 66, 44, 69, 58, 20, 30, 77, 58, 87, 22, 32, 72, 74, 39, 21, 87, 60, 69, 77, 52, 59, 46, 51, 26, 73, 55, 77, 66, 39, 20, 41, 86, 74, 44, 59, 73, 52, 77, 22, 81, 61, 58, 59, 28, 68, 81, 83]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1= ax1. boxplot(edades,
                      vert=True,# vertical box alignment
                      patch_artist=True) # fill with color
ax1.set_title( 'Edades Encuesta 1')
bplot2 = ax2.boxplot(edades2,
                      vert=True, # vertical box alignment
                      patch_artist=True) # fill with color
ax2. set_title( 'Edades Encuesta 2')
plt.show()

# %%
edades2.append(130)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1= ax1. boxplot(edades,
                     vert=True,# vertical box alignment
                     patch_artist=True) # fill with color
ax1. set_title( 'Edades Encuesta 1')
bplot2 = ax2. boxplot(edades2,
                      vert=True, # vertical box alignment
                      patch_artist=True) # fill with color
ax2. set_title( 'Edades Encuesta 2')
plt.show()
